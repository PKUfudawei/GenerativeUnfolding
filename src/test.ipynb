# %%
from models.SiT import SiT

# %%
model = SiT(depth=6, hidden_size=128, num_heads=4, mlp_ratio=2.0, use_conditions=True)
sum(p.numel() for p in model.parameters() if p.requires_grad)
# Out:
# 1503617
